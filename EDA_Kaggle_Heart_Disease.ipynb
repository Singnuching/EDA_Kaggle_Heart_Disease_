# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option("display.max_rows",5000)

# %%
ds = pd.read_csv('heart.csv')

# %%
ds
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# 5      58    0   0       100   248    0        0      122      0      1.0
# 6      58    1   0       114   318    0        2      140      0      4.4
# 7      55    1   0       160   289    0        0      145      1      0.8
# 8      46    1   0       120   249    0        0      144      0      0.8
# 9      54    1   0       122   286    0        0      116      1      3.2
# 10     71    0   0       112   149    0        1      125      0      1.6
# 11     43    0   0       132   341    1        0      136      1      3.0
# ...

# %%
ds.columns.values
# Out:
# array(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype=object)

# %%
print(ds)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# 5      58    0   0       100   248    0        0      122      0      1.0
# 6      58    1   0       114   318    0        2      140      0      4.4
# 7      55    1   0       160   289    0        0      145      1      0.8
# 8      46    1   0       120   249    0        0      144      0      0.8
# 9      54    1   0       122   286    0        0      116      1      3.2
# 10     71    0   0       112   149    0        1      125      0      1.6
# 11     43    0   0       132   341    1        0      136      1      3.0
# ...

# %% [markdown]
# # Columns description
#
#     1.age
#     2.sex
#     3.chest pain type (4 values)
#     4.resting blood pressure
#     5.serum cholestoral in mg/dl
#     6.fasting blood suger >120mg/dl
#     7.resting electrocardiographic results(values 0,1,2)
#     8.maximum heart rate achieved
#     9.excercise induced angina
#     10.oldpeak = ST depression induced by exercise relative to test
#     11.the slope of the peak excercise ST segment
#     12.number of major vessels(0-3)colored by flourosopy
#     13.thal:0=normal, 1=fixed defect, 2=reversable defect
#     14.The names and social security numbers of the patients were recently removed from the database, replaced with dummy values

# %%
ds.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
ds.hist(bins = 50, grid = False, figsize = (20,15));

# %%
ds.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# # Data Analysis

# %%
Questions = ["1.How many people have heart disease and how many people doesn't have heart disease?",
    "2.People of which sex has most heart disease?",
    "3.People of which sex has which type of chest pain most?",
    "4.People with which chest pain are most pron to have heart disease?",
    "5. Age vs maximum heart rate when people have heart disease?",
    "6.Age vs maximum heart disease when people doesn't have heart disease?",
    "7.Age vs serum cholestoral when people have heart disease?",
    "8.Age vs serum cholestoral when people doesn't have heart disease?",
    "9.People of which sex has more exercise induced angina?",
    "10.which sex of people has more fasting blood suger > 120mg/dl? "]

# %% [markdown]
# # #Finding answer of first question

# %%
ds.target.value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
ds.target.value_counts().plot(kind ="bar", color=['orchid', 'salmon'])
plt.title("Heart disease")
plt.xlabel('1 = disease, 0 = No disease')
plt.ylabel('Amount');

# %%
ds.target.value_counts().plot(kind = 'pie', figsize=(8,6))
plt.legend(["Disease", "NO disease"])

# %%
sns.kdeplot(x='age', y='thalach', data=ds, color='darkgreen');

# %% [markdown]
# # Finding answer of second question

# %%
ds.sex.value_counts()
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
ds.sex.value_counts().plot(kind = "pie")
plt.legend(['male', 'female']);

# %%
pd.crosstab(ds.sex, ds.target)
# Out:
# target    0    1
# sex
# 0        86  226
# 1       413  300

# %%
sns.countplot(x='target', data = ds, hue='sex');

# %% [markdown]
# # Finding answer of 3rd question

# %%
ds.cp.value_counts()
# Out:
# 0    497
# 2    284
# 1    167
# 3     77
# Name: cp, dtype: int64

# %%
ds.cp.value_counts().plot(kind='bar', color=['salmon', 'lightskyblue', 'springgreen','khaki'])
plt.title("Chest pain vs number of people");

# %%
pd.crosstab(ds.sex, ds.cp)
# Out:
# cp     0    1    2   3
# sex
# 0    133   57  109  13
# 1    364  110  175  64

# %%
pd.crosstab(ds.sex,ds.cp).plot(kind='bar', color=['coral', 'lightskyblue','plum', 'khaki'])
plt.title("Types of chest pain w.r.t sex")
plt.xlabel('0=female, 1= male');

# %% [markdown]
# # Finding answer of 4th question

# %%
pd.crosstab(ds.cp,ds.target)
# Out:
# target    0    1
# cp
# 0       375  122
# 1        33  134
# 2        65  219
# 3        26   51

# %%
sns.countplot(x='cp', data=ds, hue='target');

# %% [markdown]
# # Finding answer of 5&6

# %%
sns.displot(x='age',data=ds,bins=30,kde='True');

# %%
questions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 questions
#
# NameError: name 'questions' is not defined

# %%
plt.figure(figsize = (10,6))
plt.scatter(ds.age[ds.target == 1],
           ds.thalach[ds.target == 1],
           c = 'tomato')

plt.scatter(ds.age[ds.target == 0],
           ds.thalach[ds.target == 0],
           c = 'lightgreen')
plt.title("Maximum heart rate vs age")
plt.xlabel("Age")
plt.ylabel("Max heart rate")
plt.legend(['Disease', 'No disease']);

# %% [markdown]
# # 7&8

# %%
plt.figure(figsize = (10,6))
plt.scatter(ds.age[ds.target == 1],
           ds.chol[ds.target == 1],
           c = 'salmon')

plt.scatter(ds.age[ds.target == 0],
           ds.chol[ds.target == 0],
           c = 'lightblue')
plt.title("Serum cholestoral vs age")
plt.xlabel("Age")
plt.ylabel("Serum cholestoral")
plt.legend(['Disease', 'No disease']);

# %% [markdown]
# # Finding answer f question 9

# %%
ds
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# 5      58    0   0       100   248    0        0      122      0      1.0
# 6      58    1   0       114   318    0        2      140      0      4.4
# 7      55    1   0       160   289    0        0      145      1      0.8
# 8      46    1   0       120   249    0        0      144      0      0.8
# 9      54    1   0       122   286    0        0      116      1      3.2
# 10     71    0   0       112   149    0        1      125      0      1.6
# 11     43    0   0       132   341    1        0      136      1      3.0
# ...

# %%
sns.countplot(x="exang", data=ds, hue='sex')
plt.title("Exercise induced angina w.r.t sex");

# %%
sns.countplot(x="fbs", data=ds, hue='sex')
plt.title("Fasting blood suger w.r.t sex");
